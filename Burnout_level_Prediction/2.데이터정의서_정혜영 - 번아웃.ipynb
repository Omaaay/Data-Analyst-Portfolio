# %% [markdown]
# # [데이터 명세]

# %% [markdown]
# ### 캐글 데이터셋 - [Are Your Employees Burning Out?]

# %% [markdown]
# ### 1.   데이터 정의

# %% [markdown]
# * 9개의 열 / 22,750개의 데이터
# * ![image.png](attachment:5983d64e-5088-449e-813c-ad0c85fa5585.png)

# %% [markdown]
# ### 2. 수집 방법

# %% [markdown]
# * 캐글 데이터셋

# %% [markdown]
# ### 3. 수집 경로

# %% [markdown]
# 해커어스 챌린지
# UPDATED 3 YEARS AGO
# * https://www.kaggle.com/datasets/blurredmachine/are-your-employees-burning-out/data?select=sample_submission.csv
#
# * https://www.hackerearth.com/challenges/new/competitive/hackerearth-machine-learning-challenge-predict-burnout-rate/

# %% [markdown]
# ### 4.   데이터의 논리적 구조

# %% [markdown]
# #### 키(Key)
# - 아이디 컬럼(유니크 컬럼) : employee_ID
# #### 속성(Attributes)
# - 데이터를 구성하는 특징들의 속성(연속형, 범주형)
# * nunumeric_cols = ['Designation', 'Resource Allocation', 'Mental Fatigue Score', 'Burn Rate'],
# *
# category_cols = ['Employee ID', 'Date of Joining', 'Gender', 'Company Type', 'WFH Setup Available']

# %% [markdown]
# #### 결측값 확인
# ![image.png](attachment:0c1cd636-0540-483c-91f1-37215f02a1cc.png)

# %% [markdown]
# ### 5.   데이터의 물리적 저장 구조

# %% [markdown]
# * sample_submissin.csv (167 B) -샘플 제출 양식
# * test.csv (788.1 kB) -훈련데이터
# * train.csv  (1.56 MB) -샘플데이터

# %% [markdown]
# - 캐글 API를 통해 파일 다운로드
