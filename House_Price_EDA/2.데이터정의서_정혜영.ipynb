# %% [markdown]
# # [데이터 명세]

# %% [markdown]
# ### 캐글 데이터셋 - [인도 6개 대도시별 임대료 예측을 위한 임대료 데이터셋 분석]

# %% [markdown]
# ### 1.   데이터 정의

# %% [markdown]
# * 12개의 행 / 4746개의 데이터

# %% [markdown]
# ### 2. 수집 방법

# %% [markdown]
# * 캐글 데이터셋
# .

# %% [markdown]
# ### 3.   수집 경로

# %% [markdown]
# * 수집된 방법 : 인도 부동산 사이트 '매직브릭스'의 임대 매물 수집 데이터 \
# https://www.magicbricks.com/

# %% [markdown]
# ### 4.   데이터의 논리적 구조

# %% [markdown]
# #### 아이디 컬럼 없음
# #### 결측값 없음
#
# #### About the dataset (12columns)
# ![image.png](attachment:dc5c7f4b-b279-4d57-a512-1c67ecf553b4.png)lats. 컨택 포인트

# %% [markdown]
# ### 5.   데이터의 물리적 저장 구조

# %% [markdown]
# * House_Rent_Dataset.csv(제출용)
