# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from category_encoders import BinaryEncoder, OrdinalEncoder
from sklearn.impute import SimpleImputer 
from sklearn.metrics import fbeta_score, roc_auc_score
import time
from pycaret.classification import *
import shap

# %%
df = pd.read_csv('loan_data.csv', low_memory=False)
df_ind = df[(df.application_type == "Individual")]

# %%
#총 21개 컬럼 (annual inc(특성 엔지니어링에 사용후 제거)
select_features = ["loan_amnt", "term", "int_rate", "installment", "sub_grade",
                    "emp_length", "verification_status", "addr_state", "dti", 
                    "fico_range_low", "fico_range_high", "last_fico_range_high", "last_fico_range_low",
                    "avg_cur_bal", "open_acc", "revol_util", "total_acc", 'annual_inc',
                    "mo_sin_old_rev_tl_op", "mo_sin_rcnt_rev_tl_op", "pct_tl_nvr_dlq", "loan_status"]

target = "loan_status"

# %%
df = df_ind[select_features].dropna()
X, y = df.loc[:, [column for column in df.columns if column != target]], df.loan_status
#Charged Off : 1 / Fully Paid : 0으로 라벨인코딩
binary_y = y.replace({'Charged Off': 1, 'Fully Paid': 0})
X_train, X_1, label_y_train, label_y_1 = train_test_split(X, binary_y, test_size=0.2, random_state=6, stratify=binary_y)
X_val, X_test, y_val, y_test = train_test_split(X_1, label_y_1, test_size=0.5, random_state=6, stratify=label_y_1)

# %%
data = pd.concat((X_train, label_y_train), axis=1)
test = pd.concat((X_val, y_val), axis=1)

# %%
def new_features(df):
    transformed_df = df.copy()
    
    #dti 0~40으로 제한
    transformed_df['dti'] = np.clip(transformed_df['dti'], 0, 40)

    #비율 특성 0~100으로 제한
    for col in ['revol_util', 'pct_tl_nvr_dlq']:
        transformed_df[col] = np.clip(transformed_df[col], 0, 100)

    # installment_rate : 전체 대출액대비 한달 상환액의 비율
    transformed_df['installment_ratio'] = transformed_df['installment'] / transformed_df['loan_amnt']

    # installment_rate : 전체 대출액대비 한달 상환액의 비율
    transformed_df['loan_vs_inc'] =  transformed_df['loan_amnt'] / (transformed_df['annual_inc'] + 1) #annual_inc==0인 값도 있으므로 분모 0를 방지하기 위헤 1을 더함
    transformed_df.drop(columns=['loan_amnt','annual_inc'], inplace=True)
    
    #CountEncoding
    state_counts = transformed_df['addr_state'].value_counts()
    transformed_df['addr_state_count'] = transformed_df['addr_state'].map(state_counts)
    transformed_df.drop(columns=['addr_state'], inplace=True)

    #avg_cur_bal 구간화
    # 동등한 분포를 가진 5구간 계산
    transformed_df['avg_cur_bal_level'] = pd.qcut(transformed_df['avg_cur_bal'], 5, labels=[1,2,3,4,5])
    transformed_df.drop(columns=['avg_cur_bal'], inplace=True)
    
    #mo_sin_rcnt_rev_tl_op 구간화
    # 동등한 분포를 가진 4구간 계산
    transformed_df['mo_sin_rcnt_rev_tl_op_level'] = pd.qcut(transformed_df['mo_sin_rcnt_rev_tl_op'], 4, labels=[1,2,3,4])
    transformed_df.drop(columns=['mo_sin_rcnt_rev_tl_op'], inplace=True)

    #pct_tl_nvr_dlq
    transformed_df['pct_tl_nvr_dlq_level'] = pd.qcut(transformed_df['pct_tl_nvr_dlq'].rank(method='first'), 3, labels=[1,2,3])
    transformed_df.drop(columns=['pct_tl_nvr_dlq'], inplace=True)

    return transformed_df

# %%
pre_data = new_features(data)
pre_test = new_features(test)

# %%
pre_data.columns
# Out:
# Index(['term', 'int_rate', 'installment', 'sub_grade', 'emp_length',
#        'verification_status', 'dti', 'fico_range_low', 'fico_range_high',
#        'last_fico_range_high', 'last_fico_range_low', 'open_acc', 'revol_util',
#        'total_acc', 'mo_sin_old_rev_tl_op', 'loan_status', 'installment_ratio',
#        'loan_vs_inc', 'addr_state_count', 'avg_cur_bal_level',
#        'mo_sin_rcnt_rev_tl_op_level', 'pct_tl_nvr_dlq_level'],
#       dtype='object')

# %%
#총 22개 컬럼 
nominal_features = ["term", "sub_grade","verification_status"]
ordinal_features = {'mo_sin_rcnt_rev_tl_op_level': ["1", "2", "3", "4"],
                    'avg_cur_bal_level': ["1", "2", "3", "4", "5"],
                    'pct_tl_nvr_dlq_level' : ["1", "2", "3"],
                    "emp_length": ["< 1 year", "1 year", "2 years", "3 years", "4 years", "5 years", "6 years", "7 years", "8 years", "9 years", "10+ years"]    
                   }

numeric_features = ["int_rate", "installment",  "dti", "fico_range_low", "fico_range_high",  
                    "revol_util", "total_acc", 'open_acc', "last_fico_range_high", "last_fico_range_low", 
                    "mo_sin_old_rev_tl_op", "addr_state_count",'installment_ratio', 'loan_vs_inc']

# %%
exp = ClassificationExperiment()

# %% [markdown]
# ##  **Best** 이상치 remove_outliers = False / fold_shuffle=True / robust / all OneHot
# catboost AUC : 0.9573, Recall : 0.9251

# %%
exp.setup(data=pre_data, 
          target=target, 
          test_data=pre_test , 
          ordinal_features=ordinal_features, 
          numeric_features=numeric_features, 
          categorical_features=nominal_features, 
          max_encoding_ohe=36,
          fix_imbalance=True, 
          fix_imbalance_method="RandomUnderSampler", 
          remove_multicollinearity= True,
          multicollinearity_threshold = 0.9,
          normalize=True,
          normalize_method='robust',
          fold=3, 
          fold_shuffle=True,
          session_id=6)
# Out:
# <style type="text/css">
# #T_3a2a9_row10_col1, #T_3a2a9_row16_col1, #T_3a2a9_row18_col1, #T_3a2a9_row20_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_3a2a9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3a2a9_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_3a2a9_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3a2a9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3a2a9_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_3a2a9_row0_col1" class="data row0 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_3a2a9_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3a2a9_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_3a2a9_row1_col1" class="data row1 col1" >loan_status</td>
#     </tr>
#     <tr>
#       <th id="T_3a2a9_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_3a2a9_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_3a2a9_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_3a2a9_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_3a2a9_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_3a2a9_row3_col1" class="data row3 col1" >(1060568, 22)</td>
#     </tr>
#     <tr>
#       <th id="T_3a2a9_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_3a2a9_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_3a2a9_row4_col1" class="data row4 col1" >(489477, 57)</td>
#     </tr>
#     <tr>
#       <th id="T_3a2a9_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_3a2a9_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_3a2a9_row5_col1" class="data row5 col1" >(371636, 57)</td>
#     </tr>
#     <tr>
#       <th id="T_3a2a9_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_3a2a9_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_3a2a9_row6_col1" class="data row6 col1" >(117841, 57)</td>
#     </tr>
#     <tr>
#       <th id="T_3a2a9_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_3a2a9_row7_col0" class="data row7 col0" >Ordinal features</td>
#       <td id="T_3a2a9_row7_col1" class="data row7 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_3a2a9_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_3a2a9_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_3a2a9_row8_col1" class="data row8 col1" >14</td>
#     </tr>
#     <tr>
#       <th id="T_3a2a9_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_3a2a9_row9_col0" class="data row9 col0" >Categorical features</td>
#       <td id="T_3a2a9_row9_col1" class="data row9 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_3a2a9_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_3a2a9_row10_col0" class="data row10 col0" >Preprocess</td>
#       <td id="T_3a2a9_row10_col1" class="data row10 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_3a2a9_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_3a2a9_row11_col0" class="data row11 col0" >Imputation type</td>
#       <td id="T_3a2a9_row11_col1" class="data row11 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_3a2a9_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_3a2a9_row12_col0" class="data row12 col0" >Numeric imputation</td>
#       <td id="T_3a2a9_row12_col1" class="data row12 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_3a2a9_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_3a2a9_row13_col0" class="data row13 col0" >Categorical imputation</td>
#       <td id="T_3a2a9_row13_col1" class="data row13 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_3a2a9_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_3a2a9_row14_col0" class="data row14 col0" >Maximum one-hot encoding</td>
#       <td id="T_3a2a9_row14_col1" class="data row14 col1" >36</td>
#     </tr>
#     <tr>
#       <th id="T_3a2a9_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_3a2a9_row15_col0" class="data row15 col0" >Encoding method</td>
#       <td id="T_3a2a9_row15_col1" class="data row15 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_3a2a9_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_3a2a9_row16_col0" class="data row16 col0" >Remove multicollinearity</td>
#       <td id="T_3a2a9_row16_col1" class="data row16 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_3a2a9_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_3a2a9_row17_col0" class="data row17 col0" >Multicollinearity threshold</td>
#       <td id="T_3a2a9_row17_col1" class="data row17 col1" >0.900000</td>
#     </tr>
#     <tr>
#       <th id="T_3a2a9_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_3a2a9_row18_col0" class="data row18 col0" >Fix imbalance</td>
#       <td id="T_3a2a9_row18_col1" class="data row18 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_3a2a9_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_3a2a9_row19_col0" class="data row19 col0" >Fix imbalance method</td>
#       <td id="T_3a2a9_row19_col1" class="data row19 col1" >RandomUnderSampler</td>
#     </tr>
#     <tr>
#       <th id="T_3a2a9_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_3a2a9_row20_col0" class="data row20 col0" >Normalize</td>
#       <td id="T_3a2a9_row20_col1" class="data row20 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_3a2a9_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_3a2a9_row21_col0" class="data row21 col0" >Normalize method</td>
#       <td id="T_3a2a9_row21_col1" class="data row21 col1" >robust</td>
#     </tr>
#     <tr>
#       <th id="T_3a2a9_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_3a2a9_row22_col0" class="data row22 col0" >Fold Generator</td>
#       <td id="T_3a2a9_row22_col1" class="data row22 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_3a2a9_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_3a2a9_row23_col0" class="data row23 col0" >Fold Number</td>
#       <td id="T_3a2a9_row23_col1" class="data row23 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_3a2a9_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_3a2a9_row24_col0" class="data row24 col0" >CPU Jobs</td>
#       <td id="T_3a2a9_row24_col1" class="data row24 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_3a2a9_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_3a2a9_row25_col0" class="data row25 col0" >Use GPU</td>
#       <td id="T_3a2a9_row25_col1" class="data row25 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_3a2a9_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_3a2a9_row26_col0" class="data row26 col0" >Log Experiment</td>
#       <td id="T_3a2a9_row26_col1" class="data row26 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_3a2a9_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_3a2a9_row27_col0" class="data row27 col0" >Experiment Name</td>
#       <td id="T_3a2a9_row27_col1" class="data row27 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_3a2a9_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_3a2a9_row28_col0" class="data row28 col0" >USI</td>
#       <td id="T_3a2a9_row28_col1" class="data row28 col1" >cdc2</td>
#     </tr>
#   </tbody>
# </table>

# %%
#Best
cell_start_time = time.time() 
exp.compare_models(exclude=["knn"], fold = 5, round = 4, sort = 'AUC')
cell_end_time = time.time() 
print("CELL RUN TIME : ",cell_end_time - cell_start_time)
# Out:
# <style type="text/css">
# #T_fb544 th {
#   text-align: left;
# }
# #T_fb544_row0_col0, #T_fb544_row0_col1, #T_fb544_row0_col3, #T_fb544_row0_col4, #T_fb544_row0_col5, #T_fb544_row0_col6, #T_fb544_row0_col7, #T_fb544_row1_col0, #T_fb544_row1_col1, #T_fb544_row1_col2, #T_fb544_row1_col3, #T_fb544_row1_col4, #T_fb544_row1_col5, #T_fb544_row1_col6, #T_fb544_row1_col7, #T_fb544_row2_col0, #T_fb544_row2_col1, #T_fb544_row2_col2, #T_fb544_row2_col3, #T_fb544_row2_col4, #T_fb544_row2_col5, #T_fb544_row2_col6, #T_fb544_row2_col7, #T_fb544_row3_col0, #T_fb544_row3_col1, #T_fb544_row3_col2, #T_fb544_row3_col3, #T_fb544_row3_col4, #T_fb544_row3_col5, #T_fb544_row3_col6, #T_fb544_row3_col7, #T_fb544_row4_col0, #T_fb544_row4_col1, #T_fb544_row4_col2, #T_fb544_row4_col3, #T_fb544_row4_col4, #T_fb544_row4_col5, #T_fb544_row4_col6, #T_fb544_row4_col7, #T_fb544_row5_col0, #T_fb544_row5_col1, #T_fb544_row5_col2, #T_fb544_row5_col3, #T_fb544_row5_col4, #T_fb544_row5_col5, #T_fb544_row5_col6, #T_fb544_row5_col7, #T_fb544_row6_col0, #T_fb544_row6_col1, #T_fb544_row6_col2, #T_fb544_row6_col4, #T_fb544_row6_col5, #T_fb544_row6_col6, #T_fb544_row6_col7, #T_fb544_row7_col0, #T_fb544_row7_col2, #T_fb544_row7_col3, #T_fb544_row8_col0, #T_fb544_row8_col1, #T_fb544_row8_col2, #T_fb544_row8_col3, #T_fb544_row8_col4, #T_fb544_row8_col5, #T_fb544_row8_col6, #T_fb544_row8_col7, #T_fb544_row9_col0, #T_fb544_row9_col1, #T_fb544_row9_col2, #T_fb544_row9_col3, #T_fb544_row9_col4, #T_fb544_row9_col5, #T_fb544_row9_col6, #T_fb544_row9_col7, #T_fb544_row10_col0, #T_fb544_row10_col1, #T_fb544_row10_col2, #T_fb544_row10_col3, #T_fb544_row10_col4, #T_fb544_row10_col5, #T_fb544_row10_col6, #T_fb544_row10_col7, #T_fb544_row11_col0, #T_fb544_row11_col1, #T_fb544_row11_col2, #T_fb544_row11_col3, #T_fb544_row11_col4, #T_fb544_row11_col5, #T_fb544_row11_col6, #T_fb544_row11_col7, #T_fb544_row12_col0, #T_fb544_row12_col1, #T_fb544_row12_col2, #T_fb544_row12_col3, #T_fb544_row12_col4, #T_fb544_row12_col5, #T_fb544_row12_col6, #T_fb544_row12_col7, #T_fb544_row13_col0, #T_fb544_row13_col1, #T_fb544_row13_col2, #T_fb544_row13_col3, #T_fb544_row13_col4, #T_fb544_row13_col5, #T_fb544_row13_col6, #T_fb544_row13_col7, #T_fb544_row14_col0, #T_fb544_row14_col1, #T_fb544_row14_col2, #T_fb544_row14_col3, #T_fb544_row14_col4, #T_fb544_row14_col5, #T_fb544_row14_col6, #T_fb544_row14_col7 {
#   text-align: left;
# }
# #T_fb544_row0_col2, #T_fb544_row6_col3, #T_fb544_row7_col1, #T_fb544_row7_col4, #T_fb544_row7_col5, #T_fb544_row7_col6, #T_fb544_row7_col7 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_fb544_row0_col8, #T_fb544_row1_col8, #T_fb544_row2_col8, #T_fb544_row3_col8, #T_fb544_row4_col8, #T_fb544_row5_col8, #T_fb544_row6_col8, #T_fb544_row7_col8, #T_fb544_row8_col8, #T_fb544_row9_col8, #T_fb544_row10_col8, #T_fb544_row11_col8, #T_fb544_row12_col8, #T_fb544_row13_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_fb544_row14_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_fb544">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fb544_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_fb544_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_fb544_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_fb544_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_fb544_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_fb544_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_fb544_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_fb544_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_fb544_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fb544_level0_row0" class="row_heading level0 row0" >catboost</th>
#       <td id="T_fb544_row0_col0" class="data row0 col0" >CatBoost Classifier</td>
#       <td id="T_fb544_row0_col1" class="data row0 col1" >0.8888</td>
#       <td id="T_fb544_row0_col2" class="data row0 col2" >0.9576</td>
#       <td id="T_fb544_row0_col3" class="data row0 col3" >0.9249</td>
#       <td id="T_fb544_row0_col4" class="data row0 col4" >0.6541</td>
#       <td id="T_fb544_row0_col5" class="data row0 col5" >0.7663</td>
#       <td id="T_fb544_row0_col6" class="data row0 col6" >0.6961</td>
#       <td id="T_fb544_row0_col7" class="data row0 col7" >0.7141</td>
#       <td id="T_fb544_row0_col8" class="data row0 col8" >39.8080</td>
#     </tr>
#     <tr>
#       <th id="T_fb544_level0_row1" class="row_heading level0 row1" >lightgbm</th>
#       <td id="T_fb544_row1_col0" class="data row1 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_fb544_row1_col1" class="data row1 col1" >0.8880</td>
#       <td id="T_fb544_row1_col2" class="data row1 col2" >0.9566</td>
#       <td id="T_fb544_row1_col3" class="data row1 col3" >0.9260</td>
#       <td id="T_fb544_row1_col4" class="data row1 col4" >0.6519</td>
#       <td id="T_fb544_row1_col5" class="data row1 col5" >0.7652</td>
#       <td id="T_fb544_row1_col6" class="data row1 col6" >0.6945</td>
#       <td id="T_fb544_row1_col7" class="data row1 col7" >0.7129</td>
#       <td id="T_fb544_row1_col8" class="data row1 col8" >9.7940</td>
#     </tr>
#     <tr>
#       <th id="T_fb544_level0_row2" class="row_heading level0 row2" >xgboost</th>
#       <td id="T_fb544_row2_col0" class="data row2 col0" >Extreme Gradient Boosting</td>
#       <td id="T_fb544_row2_col1" class="data row2 col1" >0.8879</td>
#       <td id="T_fb544_row2_col2" class="data row2 col2" >0.9564</td>
#       <td id="T_fb544_row2_col3" class="data row2 col3" >0.9242</td>
#       <td id="T_fb544_row2_col4" class="data row2 col4" >0.6522</td>
#       <td id="T_fb544_row2_col5" class="data row2 col5" >0.7647</td>
#       <td id="T_fb544_row2_col6" class="data row2 col6" >0.6940</td>
#       <td id="T_fb544_row2_col7" class="data row2 col7" >0.7122</td>
#       <td id="T_fb544_row2_col8" class="data row2 col8" >12.7720</td>
#     </tr>
#     <tr>
#       <th id="T_fb544_level0_row3" class="row_heading level0 row3" >gbc</th>
#       <td id="T_fb544_row3_col0" class="data row3 col0" >Gradient Boosting Classifier</td>
#       <td id="T_fb544_row3_col1" class="data row3 col1" >0.8884</td>
#       <td id="T_fb544_row3_col2" class="data row3 col2" >0.9553</td>
#       <td id="T_fb544_row3_col3" class="data row3 col3" >0.9240</td>
#       <td id="T_fb544_row3_col4" class="data row3 col4" >0.6535</td>
#       <td id="T_fb544_row3_col5" class="data row3 col5" >0.7655</td>
#       <td id="T_fb544_row3_col6" class="data row3 col6" >0.6951</td>
#       <td id="T_fb544_row3_col7" class="data row3 col7" >0.7131</td>
#       <td id="T_fb544_row3_col8" class="data row3 col8" >40.5820</td>
#     </tr>
#     <tr>
#       <th id="T_fb544_level0_row4" class="row_heading level0 row4" >rf</th>
#       <td id="T_fb544_row4_col0" class="data row4 col0" >Random Forest Classifier</td>
#       <td id="T_fb544_row4_col1" class="data row4 col1" >0.8879</td>
#       <td id="T_fb544_row4_col2" class="data row4 col2" >0.9537</td>
#       <td id="T_fb544_row4_col3" class="data row4 col3" >0.9236</td>
#       <td id="T_fb544_row4_col4" class="data row4 col4" >0.6522</td>
#       <td id="T_fb544_row4_col5" class="data row4 col5" >0.7645</td>
#       <td id="T_fb544_row4_col6" class="data row4 col6" >0.6938</td>
#       <td id="T_fb544_row4_col7" class="data row4 col7" >0.7118</td>
#       <td id="T_fb544_row4_col8" class="data row4 col8" >22.8300</td>
#     </tr>
#     <tr>
#       <th id="T_fb544_level0_row5" class="row_heading level0 row5" >et</th>
#       <td id="T_fb544_row5_col0" class="data row5 col0" >Extra Trees Classifier</td>
#       <td id="T_fb544_row5_col1" class="data row5 col1" >0.8891</td>
#       <td id="T_fb544_row5_col2" class="data row5 col2" >0.9537</td>
#       <td id="T_fb544_row5_col3" class="data row5 col3" >0.9175</td>
#       <td id="T_fb544_row5_col4" class="data row5 col4" >0.6565</td>
# CELL RUN TIME :  1290.7405123710632

# %%
best_catboost1 = exp.tune_model(catboost, return_train_score=True, 
                                return_tuner=True, choose_better=True, custom_grid=custom_param)
# Out:
# <style type="text/css">
# #T_e2510_row6_col0, #T_e2510_row6_col1, #T_e2510_row6_col2, #T_e2510_row6_col3, #T_e2510_row6_col4, #T_e2510_row6_col5, #T_e2510_row6_col6, #T_e2510_row8_col0, #T_e2510_row8_col1, #T_e2510_row8_col2, #T_e2510_row8_col3, #T_e2510_row8_col4, #T_e2510_row8_col5, #T_e2510_row8_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_e2510">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e2510_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_e2510_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_e2510_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_e2510_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_e2510_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_e2510_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_e2510_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Split</th>
#       <th class="index_name level1" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e2510_level0_row0" class="row_heading level0 row0" rowspan="3">CV-Train</th>
#       <th id="T_e2510_level1_row0" class="row_heading level1 row0" >0</th>
#       <td id="T_e2510_row0_col0" class="data row0 col0" >0.8883</td>
#       <td id="T_e2510_row0_col1" class="data row0 col1" >0.9560</td>
#       <td id="T_e2510_row0_col2" class="data row0 col2" >0.9265</td>
#       <td id="T_e2510_row0_col3" class="data row0 col3" >0.6524</td>
#       <td id="T_e2510_row0_col4" class="data row0 col4" >0.7657</td>
#       <td id="T_e2510_row0_col5" class="data row0 col5" >0.6952</td>
#       <td id="T_e2510_row0_col6" class="data row0 col6" >0.7136</td>
#     </tr>
#     <tr>
#       <th id="T_e2510_level1_row1" class="row_heading level1 row1" >1</th>
#       <td id="T_e2510_row1_col0" class="data row1 col0" >0.8893</td>
#       <td id="T_e2510_row1_col1" class="data row1 col1" >0.9560</td>
#       <td id="T_e2510_row1_col2" class="data row1 col2" >0.9251</td>
#       <td id="T_e2510_row1_col3" class="data row1 col3" >0.6551</td>
#       <td id="T_e2510_row1_col4" class="data row1 col4" >0.7670</td>
#       <td id="T_e2510_row1_col5" class="data row1 col5" >0.6972</td>
#       <td id="T_e2510_row1_col6" class="data row1 col6" >0.7150</td>
#     </tr>
#     <tr>
#       <th id="T_e2510_level1_row2" class="row_heading level1 row2" >2</th>
#       <td id="T_e2510_row2_col0" class="data row2 col0" >0.8883</td>
#       <td id="T_e2510_row2_col1" class="data row2 col1" >0.9558</td>
#       <td id="T_e2510_row2_col2" class="data row2 col2" >0.9249</td>
#       <td id="T_e2510_row2_col3" class="data row2 col3" >0.6528</td>
#       <td id="T_e2510_row2_col4" class="data row2 col4" >0.7654</td>
#       <td id="T_e2510_row2_col5" class="data row2 col5" >0.6949</td>
#       <td id="T_e2510_row2_col6" class="data row2 col6" >0.7131</td>
#     </tr>
#     <tr>
#       <th id="T_e2510_level0_row3" class="row_heading level0 row3" rowspan="3">CV-Val</th>
#       <th id="T_e2510_level1_row3" class="row_heading level1 row3" >0</th>
#       <td id="T_e2510_row3_col0" class="data row3 col0" >0.8881</td>
#       <td id="T_e2510_row3_col1" class="data row3 col1" >0.9553</td>
#       <td id="T_e2510_row3_col2" class="data row3 col2" >0.9246</td>
#       <td id="T_e2510_row3_col3" class="data row3 col3" >0.6524</td>
#       <td id="T_e2510_row3_col4" class="data row3 col4" >0.7650</td>
#       <td id="T_e2510_row3_col5" class="data row3 col5" >0.6944</td>
#       <td id="T_e2510_row3_col6" class="data row3 col6" >0.7126</td>
#     </tr>
#     <tr>
#       <th id="T_e2510_level1_row4" class="row_heading level1 row4" >1</th>
#       <td id="T_e2510_row4_col0" class="data row4 col0" >0.8878</td>
#       <td id="T_e2510_row4_col1" class="data row4 col1" >0.9552</td>
#       <td id="T_e2510_row4_col2" class="data row4 col2" >0.9245</td>
#       <td id="T_e2510_row4_col3" class="data row4 col3" >0.6517</td>
#       <td id="T_e2510_row4_col4" class="data row4 col4" >0.7645</td>
#       <td id="T_e2510_row4_col5" class="data row4 col5" >0.6937</td>
#       <td id="T_e2510_row4_col6" class="data row4 col6" >0.7120</td>
#     </tr>
#     <tr>
#       <th id="T_e2510_level1_row5" class="row_heading level1 row5" >2</th>
#       <td id="T_e2510_row5_col0" class="data row5 col0" >0.8892</td>
#       <td id="T_e2510_row5_col1" class="data row5 col1" >0.9560</td>
#       <td id="T_e2510_row5_col2" class="data row5 col2" >0.9261</td>
#       <td id="T_e2510_row5_col3" class="data row5 col3" >0.6546</td>
#       <td id="T_e2510_row5_col4" class="data row5 col4" >0.7670</td>
#       <td id="T_e2510_row5_col5" class="data row5 col5" >0.6971</td>
#       <td id="T_e2510_row5_col6" class="data row5 col6" >0.7152</td>
#     </tr>
#     <tr>
#       <th id="T_e2510_level0_row6" class="row_heading level0 row6" rowspan="2">CV-Train</th>
#       <th id="T_e2510_level1_row6" class="row_heading level1 row6" >Mean</th>
#       <td id="T_e2510_row6_col0" class="data row6 col0" >0.8886</td>
#       <td id="T_e2510_row6_col1" class="data row6 col1" >0.9559</td>
#       <td id="T_e2510_row6_col2" class="data row6 col2" >0.9255</td>
#       <td id="T_e2510_row6_col3" class="data row6 col3" >0.6534</td>
#       <td id="T_e2510_row6_col4" class="data row6 col4" >0.7660</td>
#       <td id="T_e2510_row6_col5" class="data row6 col5" >0.6958</td>
#       <td id="T_e2510_row6_col6" class="data row6 col6" >0.7139</td>
#     </tr>
#     <tr>
#       <th id="T_e2510_level1_row7" class="row_heading level1 row7" >Std</th>
#       <td id="T_e2510_row7_col0" class="data row7 col0" >0.0005</td>
#       <td id="T_e2510_row7_col1" class="data row7 col1" >0.0001</td>
#       <td id="T_e2510_row7_col2" class="data row7 col2" >0.0007</td>
#       <td id="T_e2510_row7_col3" class="data row7 col3" >0.0012</td>
#       <td id="T_e2510_row7_col4" class="data row7 col4" >0.0007</td>
#       <td id="T_e2510_row7_col5" class="data row7 col5" >0.0010</td>
#       <td id="T_e2510_row7_col6" class="data row7 col6" >0.0008</td>
#     </tr>
#     <tr>
#       <th id="T_e2510_level0_row8" class="row_heading level0 row8" rowspan="2">CV-Val</th>
#       <th id="T_e2510_level1_row8" class="row_heading level1 row8" >Mean</th>
#       <td id="T_e2510_row8_col0" class="data row8 col0" >0.8883</td>
#       <td id="T_e2510_row8_col1" class="data row8 col1" >0.9555</td>
#       <td id="T_e2510_row8_col2" class="data row8 col2" >0.9251</td>
#       <td id="T_e2510_row8_col3" class="data row8 col3" >0.6529</td>
#       <td id="T_e2510_row8_col4" class="data row8 col4" >0.7655</td>
#       <td id="T_e2510_row8_col5" class="data row8 col5" >0.6951</td>
#       <td id="T_e2510_row8_col6" class="data row8 col6" >0.7132</td>
#     </tr>
#     <tr>
#       <th id="T_e2510_level1_row9" class="row_heading level1 row9" >Std</th>
#       <td id="T_e2510_row9_col0" class="data row9 col0" >0.0006</td>
#       <td id="T_e2510_row9_col1" class="data row9 col1" >0.0004</td>
#       <td id="T_e2510_row9_col2" class="data row9 col2" >0.0007</td>
#       <td id="T_e2510_row9_col3" class="data row9 col3" >0.0012</td>
#       <td id="T_e2510_row9_col4" class="data row9 col4" >0.0011</td>
#       <td id="T_e2510_row9_col5" class="data row9 col5" >0.0015</td>
#       <td id="T_e2510_row9_col6" class="data row9 col6" >0.0014</td>
#     </tr>
#     <tr>
#       <th id="T_e2510_level0_row10" class="row_heading level0 row10" >Train</th>
#       <th id="T_e2510_level1_row10" class="row_heading level1 row10" >nan</th>
#       <td id="T_e2510_row10_col0" class="data row10 col0" >0.8888</td>
#       <td id="T_e2510_row10_col1" class="data row10 col1" >0.9559</td>
#       <td id="T_e2510_row10_col2" class="data row10 col2" >0.9253</td>
#       <td id="T_e2510_
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Original model was better than the tuned model, hence it will be returned. NOTE: The display metrics are for the tuned model (not the original one).

# %% [markdown]
# ## bagging

# %%
#catboost : 0.9577
bag_cat = exp.ensemble_model(estimator=catboost0, fold=5, optimize = 'AUC')
# Out:
# <style type="text/css">
# #T_a6f21_row5_col0, #T_a6f21_row5_col1, #T_a6f21_row5_col2, #T_a6f21_row5_col3, #T_a6f21_row5_col4, #T_a6f21_row5_col5, #T_a6f21_row5_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_a6f21">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a6f21_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_a6f21_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_a6f21_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_a6f21_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_a6f21_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_a6f21_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_a6f21_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a6f21_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a6f21_row0_col0" class="data row0 col0" >0.8879</td>
#       <td id="T_a6f21_row0_col1" class="data row0 col1" >0.9575</td>
#       <td id="T_a6f21_row0_col2" class="data row0 col2" >0.9250</td>
#       <td id="T_a6f21_row0_col3" class="data row0 col3" >0.6521</td>
#       <td id="T_a6f21_row0_col4" class="data row0 col4" >0.7649</td>
#       <td id="T_a6f21_row0_col5" class="data row0 col5" >0.6942</td>
#       <td id="T_a6f21_row0_col6" class="data row0 col6" >0.7125</td>
#     </tr>
#     <tr>
#       <th id="T_a6f21_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a6f21_row1_col0" class="data row1 col0" >0.8890</td>
#       <td id="T_a6f21_row1_col1" class="data row1 col1" >0.9581</td>
#       <td id="T_a6f21_row1_col2" class="data row1 col2" >0.9274</td>
#       <td id="T_a6f21_row1_col3" class="data row1 col3" >0.6540</td>
#       <td id="T_a6f21_row1_col4" class="data row1 col4" >0.7671</td>
#       <td id="T_a6f21_row1_col5" class="data row1 col5" >0.6971</td>
#       <td id="T_a6f21_row1_col6" class="data row1 col6" >0.7154</td>
#     </tr>
#     <tr>
#       <th id="T_a6f21_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a6f21_row2_col0" class="data row2 col0" >0.8876</td>
#       <td id="T_a6f21_row2_col1" class="data row2 col1" >0.9570</td>
#       <td id="T_a6f21_row2_col2" class="data row2 col2" >0.9244</td>
#       <td id="T_a6f21_row2_col3" class="data row2 col3" >0.6514</td>
#       <td id="T_a6f21_row2_col4" class="data row2 col4" >0.7642</td>
#       <td id="T_a6f21_row2_col5" class="data row2 col5" >0.6933</td>
#       <td id="T_a6f21_row2_col6" class="data row2 col6" >0.7116</td>
#     </tr>
#     <tr>
#       <th id="T_a6f21_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a6f21_row3_col0" class="data row3 col0" >0.8895</td>
#       <td id="T_a6f21_row3_col1" class="data row3 col1" >0.9582</td>
#       <td id="T_a6f21_row3_col2" class="data row3 col2" >0.9261</td>
#       <td id="T_a6f21_row3_col3" class="data row3 col3" >0.6555</td>
#       <td id="T_a6f21_row3_col4" class="data row3 col4" >0.7676</td>
#       <td id="T_a6f21_row3_col5" class="data row3 col5" >0.6979</td>
#       <td id="T_a6f21_row3_col6" class="data row3 col6" >0.7158</td>
#     </tr>
#     <tr>
#       <th id="T_a6f21_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a6f21_row4_col0" class="data row4 col0" >0.8900</td>
#       <td id="T_a6f21_row4_col1" class="data row4 col1" >0.9579</td>
#       <td id="T_a6f21_row4_col2" class="data row4 col2" >0.9247</td>
#       <td id="T_a6f21_row4_col3" class="data row4 col3" >0.6570</td>
#       <td id="T_a6f21_row4_col4" class="data row4 col4" >0.7682</td>
#       <td id="T_a6f21_row4_col5" class="data row4 col5" >0.6988</td>
#       <td id="T_a6f21_row4_col6" class="data row4 col6" >0.7163</td>
#     </tr>
#     <tr>
#       <th id="T_a6f21_level0_row5" class="row_heading level0 row5" >Mean</th>
#       <td id="T_a6f21_row5_col0" class="data row5 col0" >0.8888</td>
#       <td id="T_a6f21_row5_col1" class="data row5 col1" >0.9577</td>
#       <td id="T_a6f21_row5_col2" class="data row5 col2" >0.9255</td>
#       <td id="T_a6f21_row5_col3" class="data row5 col3" >0.6540</td>
#       <td id="T_a6f21_row5_col4" class="data row5 col4" >0.7664</td>
#       <td id="T_a6f21_row5_col5" class="data row5 col5" >0.6962</td>
#       <td id="T_a6f21_row5_col6" class="data row5 col6" >0.7143</td>
#     </tr>
#     <tr>
#       <th id="T_a6f21_level0_row6" class="row_heading level0 row6" >Std</th>
#       <td id="T_a6f21_row6_col0" class="data row6 col0" >0.0009</td>
#       <td id="T_a6f21_row6_col1" class="data row6 col1" >0.0004</td>
#       <td id="T_a6f21_row6_col2" class="data row6 col2" >0.0011</td>
#       <td id="T_a6f21_row6_col3" class="data row6 col3" >0.0021</td>
#       <td id="T_a6f21_row6_col4" class="data row6 col4" >0.0016</td>
#       <td id="T_a6f21_row6_col5" class="data row6 col5" >0.0021</td>
#       <td id="T_a6f21_row6_col6" class="data row6 col6" >0.0019</td>
#     </tr>
#   </tbody>
# </table>

# %%
#catboost : 0.96
bag_cat = exp.ensemble_model(estimator=catboost0,round=2, fold=5, optimize = 'AUC')
# Out:
# <style type="text/css">
# #T_97993_row5_col0, #T_97993_row5_col1, #T_97993_row5_col2, #T_97993_row5_col3, #T_97993_row5_col4, #T_97993_row5_col5, #T_97993_row5_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_97993">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_97993_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_97993_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_97993_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_97993_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_97993_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_97993_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_97993_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_97993_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_97993_row0_col0" class="data row0 col0" >0.89</td>
#       <td id="T_97993_row0_col1" class="data row0 col1" >0.96</td>
#       <td id="T_97993_row0_col2" class="data row0 col2" >0.92</td>
#       <td id="T_97993_row0_col3" class="data row0 col3" >0.65</td>
#       <td id="T_97993_row0_col4" class="data row0 col4" >0.76</td>
#       <td id="T_97993_row0_col5" class="data row0 col5" >0.69</td>
#       <td id="T_97993_row0_col6" class="data row0 col6" >0.71</td>
#     </tr>
#     <tr>
#       <th id="T_97993_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_97993_row1_col0" class="data row1 col0" >0.89</td>
#       <td id="T_97993_row1_col1" class="data row1 col1" >0.96</td>
#       <td id="T_97993_row1_col2" class="data row1 col2" >0.93</td>
#       <td id="T_97993_row1_col3" class="data row1 col3" >0.65</td>
#       <td id="T_97993_row1_col4" class="data row1 col4" >0.77</td>
#       <td id="T_97993_row1_col5" class="data row1 col5" >0.70</td>
#       <td id="T_97993_row1_col6" class="data row1 col6" >0.72</td>
#     </tr>
#     <tr>
#       <th id="T_97993_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_97993_row2_col0" class="data row2 col0" >0.89</td>
#       <td id="T_97993_row2_col1" class="data row2 col1" >0.96</td>
#       <td id="T_97993_row2_col2" class="data row2 col2" >0.92</td>
#       <td id="T_97993_row2_col3" class="data row2 col3" >0.65</td>
#       <td id="T_97993_row2_col4" class="data row2 col4" >0.76</td>
#       <td id="T_97993_row2_col5" class="data row2 col5" >0.69</td>
#       <td id="T_97993_row2_col6" class="data row2 col6" >0.71</td>
#     </tr>
#     <tr>
#       <th id="T_97993_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_97993_row3_col0" class="data row3 col0" >0.89</td>
#       <td id="T_97993_row3_col1" class="data row3 col1" >0.96</td>
#       <td id="T_97993_row3_col2" class="data row3 col2" >0.93</td>
#       <td id="T_97993_row3_col3" class="data row3 col3" >0.66</td>
#       <td id="T_97993_row3_col4" class="data row3 col4" >0.77</td>
#       <td id="T_97993_row3_col5" class="data row3 col5" >0.70</td>
#       <td id="T_97993_row3_col6" class="data row3 col6" >0.72</td>
#     </tr>
#     <tr>
#       <th id="T_97993_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_97993_row4_col0" class="data row4 col0" >0.89</td>
#       <td id="T_97993_row4_col1" class="data row4 col1" >0.96</td>
#       <td id="T_97993_row4_col2" class="data row4 col2" >0.92</td>
#       <td id="T_97993_row4_col3" class="data row4 col3" >0.66</td>
#       <td id="T_97993_row4_col4" class="data row4 col4" >0.77</td>
#       <td id="T_97993_row4_col5" class="data row4 col5" >0.70</td>
#       <td id="T_97993_row4_col6" class="data row4 col6" >0.72</td>
#     </tr>
#     <tr>
#       <th id="T_97993_level0_row5" class="row_heading level0 row5" >Mean</th>
#       <td id="T_97993_row5_col0" class="data row5 col0" >0.89</td>
#       <td id="T_97993_row5_col1" class="data row5 col1" >0.96</td>
#       <td id="T_97993_row5_col2" class="data row5 col2" >0.93</td>
#       <td id="T_97993_row5_col3" class="data row5 col3" >0.65</td>
#       <td id="T_97993_row5_col4" class="data row5 col4" >0.77</td>
#       <td id="T_97993_row5_col5" class="data row5 col5" >0.70</td>
#       <td id="T_97993_row5_col6" class="data row5 col6" >0.71</td>
#     </tr>
#     <tr>
#       <th id="T_97993_level0_row6" class="row_heading level0 row6" >Std</th>
#       <td id="T_97993_row6_col0" class="data row6 col0" >0.00</td>
#       <td id="T_97993_row6_col1" class="data row6 col1" >0.00</td>
#       <td id="T_97993_row6_col2" class="data row6 col2" >0.00</td>
#       <td id="T_97993_row6_col3" class="data row6 col3" >0.00</td>
#       <td id="T_97993_row6_col4" class="data row6 col4" >0.00</td>
#       <td id="T_97993_row6_col5" class="data row6 col5" >0.00</td>
#       <td id="T_97993_row6_col6" class="data row6 col6" >0.00</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## 최종 예측 모델

# %%
final_model = exp.finalize_model(bag_cat)
