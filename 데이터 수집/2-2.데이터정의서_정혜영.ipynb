# %% [markdown]
# # [데이터 명세]

# %% [markdown]
# ## [데이터#1] 서울시 금연구역 정보.csv

# %% [markdown]
# ### 1.   데이터 정의

# %% [markdown]
# 서울시 금연구역 정보 (항목 : 금연구역 지역, 시군구명, 금연구역구분 등)를 제공

# %% [markdown]
# ### 2. 항목값

# %% [markdown]
# 항목(총 7개) :
# 금연구역명(상호명), 금연구역범위상세, 시군구명(25개 자치구), 금연구역구분(음식점, 의료기관 등), 소재지도로명주소, 위도, 경도
#
# ![image.png](attachment:5fdcfc15-909e-4c96-bee3-a6dc30d04ad4.png)

# %% [markdown]
# ## [데이터#2] 서울시 서부지역 관내 학교현황 정보.csv

# %% [markdown]
# ### 1.   데이터 정의

# %% [markdown]
# * 서울시 서부지역(마포구, 은평구, 서대문구)의 '유치원, 초중고등학교' 정보

# %% [markdown]
# ### 2. 항목값

# %% [markdown]
# 항목(총 4개) :
# 주소, 학교명, 학제(유치원,초등학교, 특성화고, 특목고, 특수학교 등), 행정구역(=시군구명: 마포구/은평구/서대문구)
#
# ![image.png](attachment:9e55c3bf-126e-42ae-8183-5c567cf06155.png)

# %% [markdown]
# ## [데이터#3] 서울특별시 마포구_유동인구데이터

# %% [markdown]
# ### 1.   데이터 정의

# %% [markdown]
# * 마포구 유동인구가 많은 10개 지역별 유동인구 정보 제공
#
# * 10개 지역 : '대흥역인근', 'DMC청구아파트인근', '서교동1', '서교동2', '서울여자고등학교인근', '성산시영아파트인근',
#   '합정역메세나폴리스인근','연남동빌라밀집지역','마포자이아파트인근','디지털미디어시티인근주거밀집지역'

# %% [markdown]
# ### 2. 항목값

# %% [markdown]
# 항목(총 11개) :
# 격자id, 좌측 격자 위치, 상단 격자 위치, 우측 격자 위치, 하단 격자 위치, 14세 이하 어린이 유동인구, 20세 이상 50세 미만 여성 유동 인구 21시-24시 전체 유동인구 합, 65세 이상 유동인구, 20세 이상 60세 미만 주중 유동입구 합, 주말 전체 일별평균, 지역명
#
#
# ![image.png](attachment:b66f86fb-424f-4289-b136-e5aaf647a6d1.png)

# %% [markdown]
# ## [데이터#4] 마포구_흡연시설 현황.csv & 마포구_공공흡연부스 설치 현황.csv

# %% [markdown]
# ### 1.   데이터 정의

# %% [markdown]
# * 마포구 내 사설 흡연시설 현황과 공공흡연 부스 설치 현황(데이터 1개)

# %% [markdown]
# ### 2. 항목값

# %% [markdown]
# 흡연시설 현황 데이터 항목(총 10개) :
# 연번(인덱스),시도명, 시군구명, 상호명, 소재지도로명주소, 행정동, 업종, 흡연실구분, 흡연시설형태, 데이터기준일자
#
#
# 공공 흡연부스 데이터 항목(총 6개):
# 연번(인덱스), 흡연시설형태, 흡연부스명, 도로명주소, 면적, 데이터기준일자
#
# * 2개의 데이터를 합치기 위한 구분 항목으로 '흡연부스 관리주체' 항목 추가 필요
#
# ![image.png](attachment:d25f6219-3531-4648-812a-9d0037912aa2.png)
